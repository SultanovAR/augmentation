# %%
from deeppavlov.models.augmentation import ThesaurusAug
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/sultanovar/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sultanovar/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package perluniprops to
# [nltk_data]     /Users/sultanovar/nltk_data...
# [nltk_data]   Package perluniprops is already up-to-date!
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     /Users/sultanovar/nltk_data...
# [nltk_data]   Package nonbreaking_prefixes is already up-to-date!

# %%
t = ThesaurusAug('rus', dir_path='./thesaug', freq_replace=1, with_source_token=True,\
                 beam_size=4, penalty_for_source_token=-12.45)
# Out:
# 2019-01-29 12:49:54.79 INFO in 'pymorphy2.opencorpora_dict.wrapper'['wrapper'] at line 16: Loading dictionaries from /anaconda3/envs/deeppavlov/lib/python3.6/site-packages/pymorphy2_dicts/data
# 2019-01-29 12:49:54.126 INFO in 'pymorphy2.opencorpora_dict.wrapper'['wrapper'] at line 20: format: 2.4, revision: 393442, updated: 2015-01-17T16:03:56.586168

# %%
test = ['Способности он имел совершенно исключительные, обладал огромной памятью, отличался ненасытной научной любознательностью и необычайной работоспособностью… Воистину, это была ходячая энциклопедия…',\
       'В Ленине-юноше удивляет как раз то, что, в отличие от большинства своих современников, он не выказывал никакого интереса к общественной жизни. В воспоминаниях, вышедших из-под пера одной из его сестёр до того, как железная лапа цензуры легла на всё, что писалось о Ленине, он предстаёт мальчиком чрезвычайно старательным, аккуратным и педантичным, — в современной психологии это называется компульсивным типом.']

# %%
res = t._replace_by_synonyms(test)
# Out:
# [[(1, 'Способности')], [(1, 'он')], [(1, 'имел')], [(1, 'совершенно')], [(-1.3833333333333333, 'исключительные'), (0.1111111111111111, 'необыкновенные'), (0.1111111111111111, 'непревзойдённые'), (0.1111111111111111, 'удивительные'), (0.1111111111111111, 'невероятные'), (0.1111111111111111, 'редкостные'), (0.1111111111111111, 'немыслимые'), (0.1111111111111111, 'фантастические'), (0.1111111111111111, 'неземные')], [(1, ',')], [(-4.1499999999999995, 'обладал'), (0.3333333333333333, 'располагал'), (0.3333333333333333, 'имелся')], [(-1.0374999999999999, 'огромной'), (0.08333333333333333, 'неисчислимой'), (0.08333333333333333, 'обширной'), (0.08333333333333333, 'несчётной'), (0.08333333333333333, 'громадной'), (0.08333333333333333, 'здоровенной'), (0.08333333333333333, 'огромнейшей'), (0.08333333333333333, 'бессчётной'), (0.08333333333333333, 'чудовищной'), (0.08333333333333333, 'колоссальной'), (0.08333333333333333, 'несметной'), (0.08333333333333333, 'здоровой')], [(1, 'памятью')], [(1,
# ...

# %%
res[0]
# Out:
# 'Способности он имел совершенно фантастические, располагал обширной памятью, выделялся прожорливой научной пытливостью и необыкновенной трудоспособностью … Воистину, это была ходячая энциклопедия …'

# %%
test[0]
# Out:
# 'Способности он имел совершенно исключительные, обладал огромной памятью, отличался ненасытной научной любознательностью и необычайной работоспособностью… Воистину, это была ходячая энциклопедия…'

# %%
res[1]
# Out:
# 'В Ленине-юноше удивляет как раз то, что, в отличие от большинства своих современников, он не проявлял никакого интереса к социальной жизнедеятельности. В воспоминаниях, вышедших из-под пера одной из его сестёр до того, как железная лапа цензуры легла на всё, что писалось о Ленине, он предстаёт мальчиком чрезвычайно старательным, аккуратным и педантичным, — в современной психики это представляется компульсивным типом.'

# %%
test[1]
# Out:
# 'В Ленине-юноше удивляет как раз то, что, в отличие от большинства своих современников, он не выказывал никакого интереса к общественной жизни. В воспоминаниях, вышедших из-под пера одной из его сестёр до того, как железная лапа цензуры легла на всё, что писалось о Ленине, он предстаёт мальчиком чрезвычайно старательным, аккуратным и педантичным, — в современной психологии это называется компульсивным типом.'

# %%
test = ['В Москве 15-летний подросток, который несколько дней назад был госпитализирован с ожогами 98% тела, умер в больнице.']

# %%
t._replace_by_synonyms(test)
# Out:
# [[(1, 'В')], [(1, 'Москве')], [(1, '15-летний')], [(-6.225, 'подросток'), (0.5, 'тинейджер')], [(1, ',')], [(1, 'который')], [(1, 'несколько')], [(-6.225, 'дней'), (0.5, 'деньков')], [(1, 'назад')], [(-0.7323529411764705, 'был'), (0.058823529411764705, 'случался'), (0.058823529411764705, 'присутствовал'), (0.058823529411764705, 'творился'), (0.058823529411764705, 'происходил'), (0.058823529411764705, 'бывал'), (0.058823529411764705, 'находился'), (0.058823529411764705, 'имелся'), (0.058823529411764705, 'состоял'), (0.058823529411764705, 'пребывал'), (0.058823529411764705, 'стоял'), (0.058823529411764705, 'свершался'), (0.058823529411764705, 'существовал'), (0.058823529411764705, 'являлся'), (0.058823529411764705, 'шёл'), (0.058823529411764705, 'совершался'), (0.058823529411764705, 'приключался')], [(1, 'госпитализирован')], [(1, 'с')], [(1, 'ожогами')], [(1, '98')], [(1, '%')], [(-6.225, 'тела'), (0.5, 'туловища')], [(1, ',')], [(-1.3833333333333333, 'умер'), (0.1111111111111111, 'ск
# ...

# %%
test = ['Широко распространён и довольно обычен в Европе и на юге Сибири, завезён в Северную Америку, где активно осваивает новые пространства.']

# %%
t._replace_by_synonyms(test)
# Out:
# [[(1, 'Широко')], [(-6.225, 'распространён'), (0.5, 'передан')], [(1, 'и')], [(1, 'довольно')], [(-6.225, 'обычен'), (0.5, 'обыкновенен')], [(1, 'в')], [(1, 'Европе')], [(1, 'и')], [(1, 'на')], [(1, 'юге')], [(1, 'Сибири')], [(1, ',')], [(-4.1499999999999995, 'завезён'), (0.3333333333333333, 'завожен'), (0.3333333333333333, 'поставлен')], [(1, 'в')], [(1, 'Северную')], [(1, 'Америку')], [(1, ',')], [(1, 'где')], [(1, 'активно')], [(-6.225, 'осваивает'), (0.5, 'усваивает')], [(1, 'новые')], [(1, 'пространства')], [(1, '.')]]
# ['Широко передан и довольно обыкновенен в Европе и на юге Сибири, поставлен в Северную Америку, где активно усваивает новые пространства.']

# %%
test[0]
# Out:
# 'Широко распространён и довольно обычен в Европе и на юге Сибири, завезён в Северную Америку, где активно осваивает новые пространства.'

# %%
test = ['Размер, цвет и форма могут значительно различаться в зависимости от вида или сорта, но чаще всего они имеют продолговатую цилиндрическую или трёхгранную форму, выпрямленную либо закруглённую. Длина плода варьирует в пределах от 3 до 40 см, толщина — от 2 до 8 см. Цвет кожицы может быть жёлтым, зелёным, красным или даже серебристым. Мякоть белая, кремовая, жёлтая или оранжевая.']

# %%
t._replace_by_synonyms(test)
# Out:
# [[(-6.225, 'Размер'), (0.5, 'метр')], [(1, ',')], [(1, 'цвет')], [(1, 'и')], [(-3.1125, 'форма'), (0.25, 'формочка'), (0.25, 'униформа'), (0.25, 'формовыя')], [(1, 'могут')], [(1, 'значительно')], [(-4.1499999999999995, 'различаться'), (0.3333333333333333, 'отличаться'), (0.3333333333333333, 'разниться')], [(1, 'в')], [(-3.1125, 'зависимости'), (0.25, 'несамостоятельности'), (0.25, 'обусловленности'), (0.25, 'аддикции')], [(1, 'от')], [(-1.7785714285714285, 'вида'), (0.14285714285714285, 'рода'), (0.14285714285714285, 'разряда'), (0.14285714285714285, 'образа'), (0.14285714285714285, 'облика'), (0.14285714285714285, 'типа'), (0.14285714285714285, 'класса')], [(1, 'или')], [(1, 'сорта')], [(1, ',')], [(1, 'но')], [(-3.1125, 'чаще'), (0.25, 'пуще'), (0.25, 'глуши'), (0.25, 'чащобе')], [(1, 'всего')], [(1, 'они')], [(1, 'имеют')], [(1, 'продолговатую')], [(1, 'цилиндрическую')], [(1, 'или')], [(1, 'трёхгранную')], [(-3.1125, 'форму'), (0.25, 'формовыю'), (0.25, 'униформу'), (0.25, 'форм
# ...

# %%
test
# Out:
# ['Размер, цвет и форма могут значительно различаться в зависимости от вида или сорта, но чаще всего они имеют продолговатую цилиндрическую или трёхгранную форму, выпрямленную либо закруглённую. Длина плода варьирует в пределах от 3 до 40 см, толщина — от 2 до 8 см. Цвет кожицы может быть жёлтым, зелёным, красным или даже серебристым. Мякоть белая, кремовая, жёлтая или оранжевая.']

# %%
test = ['Родился в Будайке Казанской губернии в крестьянской семье. После переезда семьи в село Балаково учился в церковно-приходской школе, но не закончил её полного курса. В детстве работал в качестве прислуги и ученика у купцов и ремесленников, затем плотничал на Волге вместе с отцом и старшими братьями. Женился вопреки воле родителей с обеих сторон на дочери священника, в браке родились два сына и дочь.']

# %%
t._replace_by_synonyms(test)
# Out:
# [[(1, 'Родился')], [(1, 'в')], [(1, 'Будайке')], [(1, 'Казанской')], [(-4.1499999999999995, 'губернии'), (0.3333333333333333, 'области'), (0.3333333333333333, 'обл')], [(1, 'в')], [(1, 'крестьянской')], [(-6.225, 'семье'), (0.5, 'семейке')], [(1, '.')]]
# ...

# %%
test
# Out:
# ['Родился в Будайке Казанской губернии в крестьянской семье. После переезда семьи в село Балаково учился в церковно-приходской школе, но не закончил её полного курса. В детстве работал в качестве прислуги и ученика у купцов и ремесленников, затем плотничал на Волге вместе с отцом и старшими братьями. Женился вопреки воле родителей с обеих сторон на дочери священника, в браке родились два сына и дочь.']

# %%
test = ['Одно из наиболее значительных произведений в творчестве Андрея Тарковского, который говорил[3], что в нём он «легально коснулся трансцендентного». Производство фильма сопровождалось множеством проблем и заняло около трёх лет. При проявке плёнки практически полностью испорчен по техническим причинам первый вариант, и картину переснимали трижды, с тремя разными операторами и художниками-постановщиками.']

# %%
t._replace_by_synonyms(test)
# Out:
# [[(1, 'Одно')], [(1, 'из')], [(1, 'наиболее')], [(-1.7785714285714285, 'значительных'), (0.14285714285714285, 'важнейших'), (0.14285714285714285, 'больших'), (0.14285714285714285, 'архиважных'), (0.14285714285714285, 'многозначительных'), (0.14285714285714285, 'важных'), (0.14285714285714285, 'приличных')], [(-6.225, 'произведений'), (0.5, 'творений')], [(1, 'в')], [(-6.225, 'творчестве'), (0.5, 'творении')], [(1, 'Андрея')], [(1, 'Тарковского')], [(1, ',')], [(1, 'который')], [(-1.1318181818181818, 'говорил'), (0.09090909090909091, 'высказывал'), (0.09090909090909091, 'проговаривал'), (0.09090909090909091, 'выговаривал'), (0.09090909090909091, 'свидетельствовал'), (0.09090909090909091, 'значил'), (0.09090909090909091, 'говаривал'), (0.09090909090909091, 'толковал'), (0.09090909090909091, 'означал'), (0.09090909090909091, 'изъявлял'), (0.09090909090909091, 'произносил')], [(1, '[')], [(1, '3')], [(1, ']')], [(1, ',')], [(1, 'что')], [(1, 'в')], [(1, 'нём')], [(1, 'он')], [(1, '«')], 
# ...

# %%
test
# Out:
# ['Одно из наиболее значительных произведений в творчестве Андрея Тарковского, который говорил[3], что в нём он «легально коснулся трансцендентного». Производство фильма сопровождалось множеством проблем и заняло около трёх лет. При проявке плёнки практически полностью испорчен по техническим причинам первый вариант, и картину переснимали трижды, с тремя разными операторами и художниками-постановщиками.']

# %%
test = ['Фильм начинается в чёрно-белой гамме с того, что трое героев, оторвавшись от военного патруля, проникают в Зону. Здесь картина становится цветной. Цель путников — найти ту самую Комнату. Выясняется, что вход в неё расположен в нескольких сотнях метров от начала пути. Сталкер требует, чтобы спутники беспрекословно подчинялись его указаниям, объясняя, что прямой путь в Зоне не самый короткий.']

# %%
t._replace_by_synonyms(test)
# Out:
# [[(1, 'Фильм')], [(-2.0749999999999997, 'начинается'), (0.16666666666666666, 'образовывается'), (0.16666666666666666, 'возникает'), (0.16666666666666666, 'создаётся'), (0.16666666666666666, 'образуется'), (0.16666666666666666, 'появляется')], [(1, 'в')], [(1, 'чёрно-белой')], [(-6.225, 'гамме'), (0.5, 'гаммовые')], [(1, 'с')], [(1, 'того')], [(1, ',')], [(1, 'что')], [(1, 'трое')], [(1, 'героев')], [(1, ',')], [(-1.7785714285714285, 'оторвавшись'), (0.14285714285714285, 'отколовшись'), (0.14285714285714285, 'отлетевши'), (0.14285714285714285, 'оборвавшись'), (0.14285714285714285, 'отшатнувшись'), (0.14285714285714285, 'откачнувшись'), (0.14285714285714285, 'отодравшись')], [(1, 'от')], [(-4.1499999999999995, 'военного'), (0.3333333333333333, 'вояки'), (0.3333333333333333, 'армейца')], [(1, 'патруля')], [(1, ',')], [(1, 'проникают')], [(1, 'в')], [(1, 'Зону')], [(1, '.')]]
# ...

# %%
test
# Out:
# ['Фильм начинается в чёрно-белой гамме с того, что трое героев, оторвавшись от военного патруля, проникают в Зону. Здесь картина становится цветной. Цель путников — найти ту самую Комнату. Выясняется, что вход в неё расположен в нескольких сотнях метров от начала пути. Сталкер требует, чтобы спутники беспрекословно подчинялись его указаниям, объясняя, что прямой путь в Зоне не самый короткий.']
